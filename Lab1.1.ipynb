# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("C:\ML Lab\Dataset.csv")


# Check basic information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       800 non-null    int64
#  1   Gender           800 non-null    object
#  2   Age              800 non-null    int64
#  3   Annual Income    800 non-null    int64
#  4   Spending Score   800 non-null    int64
#  5   Profession       788 non-null    object
#  6   Work Experience  800 non-null    int64
#  7   Family Size      800 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 50.1+ KB
# None

# %%
df.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# Age                 0
# Annual Income       0
# Spending Score      0
# Profession         12
# Work Experience     0
# Family Size         0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         CustomerID  Gender         Age  Annual Income  Spending Score  \
# count     800.0000     800  800.000000     800.000000       800.00000
# unique         NaN       2         NaN            NaN             NaN
# top            NaN  Female         NaN            NaN             NaN
# freq           NaN     470         NaN            NaN             NaN
# mean      400.5000     NaN   47.201250   95290.290000        50.70750
# std       231.0844     NaN   26.204085   49294.176042        28.44329
# min         1.0000     NaN    0.000000       0.000000         0.00000
# 25%       200.7500     NaN   26.750000   59992.750000        27.00000
# 50%       400.5000     NaN   44.500000   89231.000000        50.50000
# 75%       600.2500     NaN   67.000000  135401.000000        75.00000
# max       800.0000     NaN   99.000000  189974.000000       100.00000
#
#        Profession  Work Experience  Family Size
# count         788       800.000000   800.000000
# unique          9              NaN          NaN
# top        Artist              NaN          NaN
# freq          245              NaN          NaN
# mean          NaN         3.943750     3.405000
# std           NaN         4.266537     1.906704
# min           NaN         0.000000     1.000000
# 25%           NaN         1.000000     2.000000
# 50%           NaN         2.000000     3.000000
# 75%           NaN         7.000000     5.000000
# max           NaN        17.000000     9.000000

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
num_cols.remove('CustomerID')
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Gender', 'Profession'], dtype='object')
# Numerical Variables:
# ['Age', 'Annual Income', 'Spending Score', 'Work Experience', 'Family Size']

# %%
for col in num_cols:
    
    print(col)
    print("Median", df[col].median())
    print("Mode",df[col].mode())
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()
# Out:
# Age
# Median 44.5
# Mode 0    32
# Name: Age, dtype: int64
# Annual Income
# Median 89231.0
# Mode 0     9000
# 1    50000
# Name: Annual Income, dtype: int64
# Spending Score
# Median 50.5
# Mode 0    14
# 1    17
# 2    40
# 3    42
# 4    52
# 5    73
# Name: Spending Score, dtype: int64
# Work Experience
# Median 2.0
# Mode 0    1
# Name: Work Experience, dtype: int64
# Family Size
# Median 3.0
# Mode 0    2
# Name: Family Size, dtype: int64

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=df.drop(['Age','Annual Income'],axis=1))
plt.show()

# %%
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()
